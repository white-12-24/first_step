# %%
# 인스타 크롤링
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import WebDriverException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import undetected_chromedriver as uc
import time , tempfile 
import sys   
import math   
import pandas as pd   
import os
import random
import urllib.request
import urllib
from openpyxl.styles import Font
from openpyxl import load_workbook
from openpyxl.drawing.image import Image as XLImage
import chromedriver_autoinstaller

print('='*80)
print('< 이 프로그램은 인스타그램에서 애니 성지순례 데이터를 수집하는 프로그램 입니다.>')
print('='*80)

qu = "https://www.instagram.com/accounts/login/"

now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' %(now.tm_year, now.tm_mon, now.tm_mday, \
                                      now.tm_hour, now.tm_min, now.tm_sec)

ff = 'c:\\py_temp\\2차프로젝트\\'
if ff == '':
    ff = 'c:\\py_temp\\2차프로젝트\\'

img_dir = ff + s + '-' + '인스타그램_애니성지순례' + '\\img'

ft_name = ff+s+'-'+'인스타그램_애니성지순례'+'\\'+s+'-'+'인스타그램_애니성지순례'+'.txt'
fx_name = ff+s+'-'+'인스타그램_애니성지순례'+'\\'+s+'-'+'인스타그램_애니성지순례'+'.xlsx'
fc_name = ff+s+'-'+'인스타그램_애니성지순례'+'\\'+s+'-'+'인스타그램_애니성지순례'+'.csv'

email = input('id를 입력하세요: ')
if email == '':
    email = 'kmsoo1224@naver.com'
    
pw = input('비밀번호를 입력하세요: ')

search1 = input('검색어: ')

if search1 == '':
    search1 = '#애니성지순례'
# Out:
# ================================================================================
# < 이 프로그램은 인스타그램에서 애니 성지순례 데이터를 수집하는 프로그램 입니다.>
# ================================================================================
# id를 입력하세요:
# 비밀번호를 입력하세요:  kmsoo109!!
# 검색어:

# %%
chromedriver_autoinstaller.install(path='c:/py_temp')
driver = webdriver.Chrome()
wait = WebDriverWait(driver, 15)

driver.maximize_window()

# 🔥 인스타는 qu(검색결과/프로필/게시물)로 바로 가지 말고,
# 로그인 화면이 떠도 안정적으로 잡히게 "로그인 페이지"로 먼저 유도
driver.get("https://www.instagram.com/accounts/login/")
driver.switch_to.default_content()

# input 뜰 때까지 대기 (name이 안 먹히는 날 대비: autocomplete도 같이)
user_sel = (By.CSS_SELECTOR, "input[name='username'], input[autocomplete='username']")
pass_sel = (By.CSS_SELECTOR, "input[name='password'], input[autocomplete='current-password']")

iid2 = wait.until(EC.presence_of_element_located(user_sel))
ipwd2 = wait.until(EC.presence_of_element_located(pass_sel))

# %%
iid2.clear()
for a in email:
    iid2.send_keys(a)
    time.sleep(0.3)

ipwd2.clear()
for b in pw:
    ipwd2.send_keys(b)
    time.sleep(0.3)

# 로그인 버튼은 type=submit이 제일 안정적
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button[type='submit']"))).click()

# %%
# iid2 = driver.find_element(By.NAME,'username')
# for a in email:
#     iid2.send_keys(a)
#     time.sleep(0.5)
# ipwd2 = driver.find_element(By.NAME,'password')
# for b in pw:
#     ipwd2.send_keys(b)
#     time.sleep(0.5)

# #로그인 클릭
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="loginForm"]/div/div[3]/button/div'))).click()
# time.sleep(2)

# %%
#돋보기 클릭
wait.until(EC.element_to_be_clickable((By.LINK_TEXT,'검색'))).click()
time.sleep(2)

selector = (
    "input[type='text'][placeholder='검색'],"
    "input[type='text'][aria-label*='검색'],"
    "[role='textbox'][aria-label*='검색']"
)
search_box = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, selector)))

for c in search1:
    search_box.send_keys(c)
    time.sleep(0.5)

tag_text = search1 if search1.startswith("#") else f"#{search1}"

el = wait.until(EC.element_to_be_clickable(
    (By.XPATH, f'//a[.//*[contains(normalize-space(), "{tag_text}")]]')
))
driver.execute_script("arguments[0].scrollIntoView({block:'center'});", el)
driver.execute_script("arguments[0].click();", el)

tag = search1.lstrip("#")
driver.get(f"https://www.instagram.com/explore/tags/{tag}/")
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 #돋보기 클릭
# ----> 2 wait.until(EC.element_to_be_clickable((By.LINK_TEXT,'검색'))).click()
#       3 time.sleep(2)
#       5 selector = (
#       6     "input[type='text'][placeholder='검색'],"
#       7     "input[type='text'][aria-label*='검색'],"
#       8     "[role='textbox'][aria-label*='검색']"
#       9 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\support\wait.py:129, in WebDriverWait.until(self, method, message)
#     127 while True:
#     128     try:
# --> 129         value = method(self._driver)
#     130         if value:
#     131             return value
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\support\expected_conditions.py:624, in element_to_be_clickable.<locals>._predicate(driver)
#     622 target = mark
#     623 if not isinstance(target, WebElement):  # if given locator instead of WebElement
# --> 624     target = driver.find_element(*target)  # grab element at locator
#     625 element = visibility_of(target)(driver)
#     626 if element and element.is_enabled():
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=143.0.7499.170); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x10b1213
# 	0x10b1254
# 	0xe9e6dd
# 	0xe8d99e
# 	0xeac4e6
# 	0xf121d8
# 	0xf2d44c
# 	0xf0b2e6
# 	0xedd321
# 	0xede1d4
# 	0x1305254
# 	0x130080b
# 	0x131d0ea
# 	0x10cb118
# 	0x10d311d
# 	0x10b9518
# 	0x10b96d9
# 	0x10a3a68
# 	0x76795d49
# 	0x77b7d5db
# 	0x77b7d561

# %%
import os, time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

# =========================
# 0) 게시글 링크 수집 함수
# =========================
def collect_post_links(driver, limit=200, scroll_times=20, sleep=1.5):
    links = []
    seen = set()

    for _ in range(scroll_times):
        a_tags = driver.find_elements(By.CSS_SELECTOR, 'a[href*="/p/"]')
        for a in a_tags:
            href = a.get_attribute("href")
            if href and "/p/" in href and href not in seen:
                seen.add(href)
                links.append(href)

        if len(links) >= limit:
            break

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep)

    return links[:limit]

# =========================
# 1) (너 기존) 초기 세팅
# =========================
no = 1

no2 = []
id2 = []
write2 = []
url2 = []

os.makedirs(img_dir, exist_ok=True)
os.chdir(img_dir)

# =========================
# 2) 태그 페이지에서 링크 수집
#    (현재 driver가 태그 페이지에 들어와 있는 상태여야 함)
# =========================
post_links = collect_post_links(driver, limit=300, scroll_times=40, sleep=2)
print("수집된 게시글 링크 수:", len(post_links))

# =========================
# 3) 링크 하나씩 들어가서 추출 (너 스타일 유지)
# =========================
for r, url in enumerate(post_links, start=1):
    driver.get(url)
    time.sleep(2)  # 렌더링 대기

    html = driver.page_source
    s = BeautifulSoup(html, 'html.parser')
    c1 = s.find('div', 'x6s0dn4 x78zum5 xdt5ytf xdj266r x11t971q xat24cr xvc5jky x1n2onr6 xh8yej3')

    # c1이 못 잡히면 스킵
    if c1 is None:
        print(f"[{r}/{len(post_links)}] c1 못찾음 -> 스킵: {url}")
        continue

    no2.append(no)
    print('1. 번호: ' + str(no))

    # 아이디
    try:
        id3 = c1.find('span', 'xt0psk2').get_text()
    except:
        id3 = ""
    id2.append(id3)
    print('2. 아이디: ' + id3)

    # 본문내용 + 해시태그
    try:
        write1 = c1.find('span', 'x193iq5w xeuugli x13faqbe x1vvkbs xt0psk2 x1i0vuye xvs91rp xo1l8bm x5n08af x10wh9bi xpm28yp x8viiok x1o7cslx x126k92a').get_text()
    except:
        write1 = ""
    write2.append(write1)
    print('3. 내용: ' + write1 + '\n' + '='*90 + '\n')

    url2.append(url)
    print('4. 링크: ' + url)

    time.sleep(1)
    no += 1

print("완료! 추출된 개수:", len(no2))
# Out:
# 수집된 게시글 링크 수: 52
# 1. 번호: 1
# 2. 아이디: tour.toctoc
# 3. 내용: 여기도 실제로 있는 장소였다고?🎆#스즈메의문단속 실제 장소 총정리!🪑여기 가면 😺다이진 볼 수 있나요?💖@@도쿄 뒷문 닫으러 갈 사람!🚪아뢰옵기도 송구한 히미즈의 신이시여..!!!돌려드리옵나이다!!!🔑✈️감성적인 여행지와 공간을 담은 소개가 필요하다면?✈️@tour.toctoc 팔로우하고 당신만의 감성을 찾아보세요." Find with us ! " ✈️-게시물에 대한 문의사항과 질문은 DM해주시면 감사하겠습니다 :)#애니성지순례 #일본여행가볼만한곳 #다이진 #스즈메 #도쿄가볼만한곳 #오차노미즈 #애니성지 #여행스타그램 #해외여행 #일본자유여행 #일본여행코스 #일본여행지추천 #촬영지 #고베 #애니배경 #여행톡톡_해외
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/CrIno4UyrAy/
# 1. 번호: 2
# 2. 아이디: rakutentravel_kor
# 3. 내용: 🌿 애니 감성 그대로, 일본 소도시 여행“어? 여기 어디서 본 거 같은데?”애니 덕후라면 무조건 반가울 일본 소도시들!😆사진만 찍어도 애니 주인공 된 느낌을 느끼러 떠나보아요💫모험가를 위한 낯선 여행은#트립소다 에서
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DHk5quAPNpv/
# 1. 번호: 13
# 2. 아이디: ready_setlist
# 3. 내용: 일본 여행 전, 꼭 알아야 할 애니 성지들 모음🎬애니메이션 팬들을 위한 일본 성지순례 리스트를 모아봤어요!작품 속 장면으로만 보던 장소를직접 걸어볼 수 있는 순간✨일본 여행 계획 중이라면루트 짤 때 참고용으로 저장📌여러분의 최애 애니 성지도 댓글로 공유해주세요👇💬 더 많은 정보는 👉 @chapter.pick 💬—Edited by 박소윤Directed by 유지원Supported by 안종현#일본여행 #애니성지순례 #애니여행 #애니메이션 #애니추천 #일본애니 #성지순례 #덕후 #오타쿠 #애니그램 #여행스타그램 #체인소맨 #주술회전 #진격의거인 #향기로운꽃은늠름하게핀다 #스즈메의문단속 #너의이름은 #슬램덩크
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DTT5oLilVa8/
# 1. 번호: 14
# 2. 아이디: kyounoo
# 3. 내용: 도쿄 아키하바라 근처 , 스즈메의 문단속 배경지 “히지리바시”신카이 마코토 감독 영화 스즈메의 문단속 성지순례 코스로유명한 히지리바시에 다녀왔어요 ‼🌉️ 영화에서 여기는 재난을 막기 위한 중요한 장소로 나오죠!열차 세개가 동시에 지나가면 문단속을 할 수 있고,재난을 막을 수 있는 중요설정이 있어 열차 세개가 동시에 지나가는 타이밍을 포착하기 위해 기다렸고, 포착성공! ✨✔️POINT ✨1.열차 세개가 지나가는 타이밍을 포착하세요2.제가 포착한 시간은 평일 (목요일) 오전 8:28분 ⏰3.빨간색 열차 (마루노우치선) 배차 간격이 가장 짧아,쨍한 색감의 사진을 많이 건질 수 있어요❤️📍Yushima, Bunkyo-ku, Tokyo, 113-0034🚇 오차노미즈역 (주오본선,마루노우치선,소부선)히지리바시 출구 도보 1분
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DPKvlqLkxQo/
# 1. 번호: 15
# 2. 아이디: tri.pwithu
# 3. 내용: ✨ 도쿄 — 애니메이션 성지 투어 🎌도쿄는 그 자체가 애니메이션의 무대이자 팬들의 꿈의 도시!이번엔 오타쿠들의 천국이라 불리는 애니 성지 3곳을 함께 돌아볼까요? 💫1️⃣ 아키하바라 (Akihabara)피규어, 굿즈, 메이드카페까지!거리 전체가 애니와 게임으로 물든 ‘진짜 성지’.「러브라이브!」, 「스즈미야 하루히」 팬이라면 무조건 필수 코스!2️⃣ 이케부쿠로 선샤인시티 & 오토메로드여성향 애니 팬들의 낙원 ✨「하이큐!!」, 「블루록」, 「주술회전」 등 인기작 팝업이 열리는 곳!분홍빛 감성 가득한 덕질 천국 💕3️⃣ 도쿄 애니메이션 센터한정 전시 + 콜라보 카페 + 굿즈샵까지 한자리!📸 이번 주말, 당신의 덕심을 채워줄도쿄 애니메이션 성지 투어로 떠나볼까요?#도쿄여행 #애니성지투어 #아키하바라 #이케부쿠로 #오토메로드 #도쿄타워 #도쿄애니메이션센터 #일본여행 #오타쿠투어 #애니덕질 #애니성지순례 #AnimeTrip #TokyoAnimeTour #TripWithU
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DQF_s0XkvPp/
# 1. 번호: 16
# 2. 아이디: arza_sangeun
# 3. 내용: #너의이름은 #갱스럽게 #애니성지순례 #굿모닝도쿄명작애니에 상은 뿌리기~🤣🤣🤣오타쿠스런 일본에서의 마지막 아침 맞이 완료🙋🏻‍♂️.최애 애니중 하나인, ‘너의 이름은’에서 나온  바로 그 계단!숙소에서 달리는 내내 너의이름은 OST를 들으며 도쿄에서의 애니감성을 만끽할 수 있었던 시간~😍. (얼마 안되는 나의 소녀소녀 감성🤭)일본여행의 마무리를 행복하고 차분하게 마무리 해봅니다~🙋🏻‍♂️.#달리기스타그램 #런스타그램 #운동스타그램 #러닝스타그램#갱런 #갱런9기 #체력은국력 #트레일러닝 #도쿄러닝 #도심런 #오운완 #런트립 #너의이름은계단
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/C6UvKilvGrq/
# 1. 번호: 17
# 2. 아이디: tourbay_official
# 3. 내용: 📢 진격의 거인 히타코스 론칭!히타에 가야 할 이유가 또 생겼다🔥여비트립 ✈️ x 소소버스투어 🚌지금 바로 새로운 감동을 만나보세요!#진격의거인 #히타코스 #여비트립 #소소버스투어#일본여행 #여행비서 #애니성지순례
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DNzhzgx5vwj/
# 1. 번호: 18
# 2. 아이디: mokojp
# 3. 내용: #진격의거인 #애니성지순례 일본 국내에서 진격의 거인 연재 10주년 기념 프로젝트로 클라우드 펀딩을 시작, 자금을 모아 만든 동상 제1탄!설정은 댐을 진격의 거인들이 만든 성으로 설정하고 소년 시절의 엘렌, 미카사, 아르민이 거인을 처음 만나 놀라고 공포스러운 표정을 재현했습니다.여기서 앱을 켜면 벽을 만든 초대형 거인이 주인공 동상 옆에 있는 나를 내려다본다는요! 동상과 함께 이게 정말 보고 싶었어요!핸드폰 진동이면 소리까지 키워보세요! 진짜 일본 애니 성지 앱 대박입니다!!일본 문화청 주관, 애니메이션 투어리즘 협회가 기획한 '일본 애니 성지 순례 1편'오이타현 진격의 거인 성지와 콜라보 총정리프로필 상단 링크에서 확인하고오이타현 여행하시는 진격거 팬분들은 꼭 한번 들러보세요!#꿈블인스타
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DCmJwrXvhcC/
# 1. 번호: 19
# 2. 아이디: iroirotokyo
# 3. 내용: 아와지시 나루토 파크는 일본 효고현 아와지섬에 위치한 애니메이션 테마파크로, 인기 애니메이션 '나루토'와 '보루토'의 세계를 체험할 수 있는 공간입니다. 이곳은 '니지겐노모리'라는 애니메이션 테마파크 내에 있으며, 다양한 어트랙션과 체험 프로그램을 통해 방문객들에게 특별한 경험을 선사합니다.​🌀 주요 어트랙션화영암(Hokage Rock) 재현: 애니메이션 속 호카게들의 얼굴이 새
장해둬 ✨더 자세한 루트맵과 숨겨진 명소들은 프로필 링크 블로그에서 확인하세요!#일본여행 #애니성지순례 #포켓몬센터 #지브리박물관 #아키하바라 #일본여행팁 #오타쿠여행 #도쿄여행 #애니굿즈 #피규어 #일본여행정보 #성지순례 #애니메이션 #일본문화 #오덕여행 #도쿄명소 #일본쇼핑 #여행꿀팁 #해외여행 #애니덕후#일본골프#규슈골프#투어니티
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DOawj32E6DY/
# 1. 번호: 25
# 2. 아이디: tri.pwithu
# 3. 내용: ✨ [교토 애니메이션 투어] 스튜디오 견학 & 역사 탐방 ✨만화와 애니메이션을 사랑한다면 꼭 들러야 할 두 곳!교토 국제만화박물관에서는 일본 만화의 역사와 작가의 숨결을 느끼고,도에이 애니메이션 뮤지엄에서는 드래곤볼과 원피스의 세계를 직접 체험해보세요 🎨“한 장면 한 장면이 추억이 되는 여행”교토의 감성과 애니의 열정이 만나는 곳 🌸#교토여행 #일본여행 #애니메이션투어 #만화박물관 #도에이애니메이션뮤지엄#교토국제만화박물관 #드래곤볼성지 #원피스투어 #세일러문 #애니성지순례#TripWithU #체험여행 #문화여행 #일본체험 #교토핫플 #여행감성#교토데이트코스 #교토여행추천 #애니덕후여행 #감성여행
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DQDx0VWEWXL/
# 1. 번호: 26
# 2. 아이디: q.dragon11
# 3. 내용: 짧은 도쿄 여행중 #너의이름은#너의이름은성지순례#애니성지순례#yourname#일본여행#도쿄여행#여행스타그램#일본여행스타그램
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/Csc3Snjvu5M/
# 1. 번호: 27
# 2. 아이디: happy.miah
# 3. 내용: #첫줄분고모리기관고 바로 옆 기찻길!!기차가 지나갈 시간이 되면 차단봉이 내려와요!!워낙 시골이라 기차는 거의 안 다니지만 한번씩 지나가는 기차를 보고 있자면 뭔가 일본 영화의 한 장면을 보는듯한 느낌...😌✅확실히 필름 씌운거랑 아닌거랑 느낌이 다르죠?🤭...#분고모리기관고 #분고모리역 #분고모리기관고공원 #스즈메의문단속🚪#애니성지순례 #豊後森機関庫 #豊後森機関庫公園 #豊後森駅 #豊後森駅機関庫 #豊後森駅機関庫公園 #豊後森機関車庫 #豊後森機関庫転車台 #すずめの戸締まり #雀の戸締り
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DJILEIIz9iC/
# 1. 번호: 28
# 2. 아이디: jester9226
# 3. 내용: #짱구 #애니성지순례
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DDRYDGKPFkC/
# 1. 번호: 29
# 2. 아이디: sif_selfrecord
# 3. 내용: 「デンジ君ホントはね、」
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DPl-r0GiRAg/
# 1. 번호: 30
# 2. 아이디: reallllina
# 3. 내용: #도쿄여행 #신쥬쿠공원 #언어의정원#애니성지순례 #추억을놓고온곳 #그날그때 #선팔맞팔얼마전 다녀온곳 사진이 지워져서~다시 !애니 성지순례 하고 도쿄지하철완전정복 ~ 누군가 너무 생각 나는 그곳~신쥬공원에서 언어의정원 다시보기 ^^;
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/Bjr2UOKlyCv/
# 1. 번호: 42
# 2. 아이디: b612lyrics
# 3. 내용: 아오모리, 탓피곶, 애니메이션 클라나드 실제무대AOMORI, Tappi Misaki, Ani Clannad Real Spot#아오모리 #aomori #탓피곶 #tappimisaki #탓피자키 #클라나드 #clannad #애니성지순례 #애니무대 #무대탐방 #anime #animation #クラナド #keysoundslabel
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DSC2nGBgWUh/
# 1. 번호: 43
# 2. 아이디: jester9226
# 3. 내용: #애니성지순례 #내마위 #언어의정원
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DDOzgdSPOKU/
# 1. 번호: 44
# 2. 아이디: q.dragon11
# 3. 내용: 일드 애니 덕후라면 가야할 지나가야할 그곳!! 드라마에서만 보다가 방문ㅠ 감동😭😭👍👍 #경시청#일드#일본애니#명탐정코난#일드성지순례#애니성지순례#일본여행#도쿄여행#여행스타그램#일본여행스타그램
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/Csd-ulgvvaX/
# 1. 번호: 45
# 2. 아이디: iroirotokyo
# 3. 내용: #스기나미 애니메이션 박물관(杉並アニメーションミュージアム, Suginami Animation Museum) 🎥✨**스기나미 애니메이션 박물관(Suginami Animation Museum)**은 일본 애니메이션의 역사와 제작 과정을 체험할 수 있는 무료 박물관으로, 애니메이션 팬이라면 꼭 방문해야 할 도쿄의 숨은 명소입니다.일본 애니메이션의 발전 과정부터 최신 작품까지 다양한 전시가 있으며, 애니메이션 더빙 체험, 작화 체험 등 직접 참여할 수 있는 콘텐츠가 많아 애니메이션을 더욱 깊이 이해할 수 있는 곳입니다."애니메이션 덕후라면 꼭 가봐야 할 스기나미 애니메이션 박물관!" 🎬🎨"일본 애니메이션의 역사부터 제작 과정까지! 무료로 즐길 수 있는 도쿄의 숨은 명소, 스기나미 애니메이션 박물관을 다녀왔어요! ✨ #스기나미애니박물관 #도쿄애니메이션 #일본애니성지순례 #애니메이션제작체험 #무료관람""애니메이션 더빙 체험! 내가 성우가 된다면?" 🎙️🎭"애니메이션 제작 과정 체험 ✏️🎞작화(셀 애니메이션) 체험:직접 애니메이션을 그려보고, 셀 애니메이션이 어떻게 만들어지는지 체험 가능.더빙 체험:성우처럼 애니메이션 캐릭터의 대사를 직접 녹음해 볼 수 있음!촬영 & 편집 체험:애니메이션 장면을 직접 편집하고 효과를 추가하는 경험이 가능. 애니메이션 제작자가 되어보는 특별한 기회! #성우체험 #더빙체험 #도쿄애니박물관 #애니메이션덕후 #애니성지순례""인기 애니메이션 기획 전시!" ✏️📽️"시즌별로 특정 애니메이션 작품의 기획전이 열림.과거에는 "명탐정 코난", "드래곤볼", "신세기 에반게리온" 등 인기 작품 관련 전시가 개최됨.기획전은 
# 4. 링크: https://www.instagram.com/p/C4-PUPWvitr/
# 1. 번호: 47
# 2. 아이디: 1girl1cat1bike
# 3. 내용: The Only one Prison museum in Japan👮 #mustvisit메이지시대에 실제로 쓰여왔던, #아바시리감옥 을 다녀왔다! (#골든카무이 배경지!)홋카이도에서도 가장 북동쪽에 위치한 아바시리 감옥(網走監獄）은 혹독한 추위로 악질이 심한 죄수들의 잡혀오는 곳이라네..!실제로 쓰인 감옥을 만져도 보고 안에도 들어갈 수 있는데.. 실제 상황 재현하는 사람인형(?)이 너무나도 리얼해서 상당히 무섭..ㅠ..그리고 먼가 튀어나올것 같아...ㅜ(그래서 사진도 별로 안찍었었네)  실제 감옥을 박물관으로 만든것 자체도 대단한데, 너무나도 새롭고 볼거리가 많다!아바시리(網走)에 간다면, 반드시 강.추. !!明治時代に実際に使われていた #網走監獄　に行ってきたー！北海道でも北東の方にある網走監獄は、とても過酷な寒さで、罪が重い囚人が入ったらしい。実際に使われてた監獄を触ったり入れたりするんだけど、再現のためにある人形がリアルすぎて、怖いー！（なので写真もあまり撮ってなかったw)でも、実際の監獄を博物館に作ったこと自体もすごいけど、色々見どころが多いので、網走に行くならここは #必ず行くべき !...#박물관투어#애니성지순례#아바시리여행#감옥#반드시가봐야할곳 #홋카이도바이크여행#홋카이도여행 #아바시리여행#アニメ聖地#ゴールデンカムイ#北海道ツーリング#網走ツーリング #cbr650r#여행에미치다
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/CFcF6nKpOlt/
# 1. 번호: 48
# 2. 아이디: holdingwind
# 3. 내용: 🚊도토리현으로 떠난 코난투어. 일본 현지 본판의 코난 스탬프 투어는 좀 더 컨텐츠가 많은것 같은데, 한국 관광객들을 위한 코난 투어는 약간 빈약해서 아쉬웠다. 그런데 짧은 기간에 방문하는 관광객을 대상으로 만든거라 최선이었겠지만, 기념품과 퀴즈 다 풀고 나서 받는 리워드 기념품은 너무나도 아쉬웠다. -#코난투어 #명탐정코난 #돗토리여행 #성지순례#DetectiveConan #ConanTour #GoshoAoyama#名探偵コナン #コナンの旅 #聖地巡礼 #青山剛昌ふるさと館#일본여행 #애니성지순례 #여행기록#JapanTrip #MysteryVibes #アニメの世界へ#돗토리현 #コナン通り #북栄町#TravelJapan #ConanLovers
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DMXNfnFBV4i/
# 1. 번호: 49
# 2. 아이디: fishhunter_jo
# 3. 내용: #스타벅스 #스타벅스그램 #카라멜프라푸치노 #낙지시즌 #달인 #도쿄여행 #도쿄타워 #nike목포에 물건배달과 이것저것 볼일보면서 간만에 스타벅스 프라치노 한잔.겁,2물 물때라 낙지가 금방 잘잡히다 말아버리넹.그래도 좋고 저래도 좋고.낙지값 내일부터 비싸집니다.  참고들하셔용~~~어획량이줄면 오르고 아시져잉?#일상스타그램🐥
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/Cy0bSIiSMzZ/
# 1. 번호: 50
# 2. 아이디: ppekkuu
# 3. 내용: 高山　氷菓.....@sungye01  #워킹홀리데이 #일본워킹홀리데이 #일본워홀 #오사카 #오사카여행 #japan #japantrip #japantravel #japanworkingholiday #osaka #大阪 #大阪市 #오사카갈만한곳 #오사카여행지 #오사카근교 #오사카여행 #빙과 #성지순례 #빙과성지순례 #애니성지순례 #다카야마 #다캬아마여행 #나고야 #나고야여행 #nagoya #takayama #hyouka #氷菓 #高山 #名古屋
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DEtStg1TcJe/
# 1. 번호: 51
# 2. 아이디: jester9226
# 3. 내용: #애니성지순례 #나만이없는거리 #훗카이도 #도마코마이 #혼여 #네다씹
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DH-_JTWy5Cz/
# 1. 번호: 52
# 2. 아이디: iroirotokyo
# 3. 내용: #스기나미 애니메이션 박물관(杉並アニメーションミュージアム, Suginami Animation Museum) 🎥✨**스기나미 애니메이션 박물관(Suginami Animation Museum)**은 일본 애니메이션의 역사와 제작 과정을 체험할 수 있는 무료 박물관으로, 애니메이션 팬이라면 꼭 방문해야 할 도쿄의 숨은 명소입니다.일본 애니메이션의 발전 과정부터 최신 작품까지 다양한 전시가 있으며, 애니메이션 더빙 체험, 작화 체험 등 직접 참여할 수 있는 콘텐츠가 많아 애니메이션을 더욱 깊이 이해할 수 있는 곳입니다."애니메이션 덕후라면 꼭 가봐야 할 스기나미 애니메이션 박물관!" 🎬🎨"일본 애니메이션의 역사부터 제작 과정까지! 무료로 즐길 수 있는 도쿄의 숨은 명소, 스기나미 애니메이션 박물관을 다녀왔어요! ✨ #스기나미애니박물관 #도쿄애니메이션 #일본애니성지순례 #애니메이션제작체험 #무료관람""애니메이션 더빙 체험! 내가 성우가 된다면?" 🎙️🎭"애니메이션 제작 과정 체험 ✏️🎞작화(셀 애니메이션) 체험:직접 애니메이션을 그려보고, 셀 애니메이션이 어떻게 만들어지는지 체험 가능.더빙 체험:성우처럼 애니메이션 캐릭터의 대사를 직접 녹음해 볼 수 있음!촬영 & 편집 체험:애니메이션 장면을 직접 편집하고 효과를 추가하는 경험이 가능.애니메이션 제작자가 되어보는 특별한 기회! #성우체험 #더빙체험 #도쿄애니박물관 #애니메이션덕후 #애니성지순례""인기 애니메이션 기획 전시!" ✏️📽️"시즌별로 특정 애니메이션 작품의 기획전이 열림.과거에는 "명탐정 코난", "드래곤볼", "신세기 에반게리온" 등 인기 작품 관련 전시가 개최됨.기획전은 일정에 따라 변경되므로 방문 전에 확인 필요! #애니메이션제작체험 #스기나미애니박물관 #일본애니의세계 #애니메이션덕후모여라""무료 입장! 도쿄에서 숨겨진 애니메이션 성지 찾기!" 🎟️"입장료 0엔! 애니메이션 도서관: 일본 애니메이션 관련 서적과 아트북을 자유롭게 열람 가능. 미니 극장: 일본의 고전 애니메이션부터 최신 단편 애니메이션까지 감상 가능.가끔 특별한 작품 상영회도 진행됨! #무료박물관 #애니메이션성지 #도쿄핫플 #애니메이션의모든것"방문 정보 & 팁 🗺️🎟️📍 위치:도쿄도 스기나미구 오기쿠보(東京都杉並区荻窪)스기나미 애니메이션 박물관 (杉並アニメーションミュージアム)🚆 가는 방법:JR 추오선(中央線) **오기쿠보역(荻窪駅)**에서 하차 후 도보 20분오기쿠보역 북쪽 출구에서 버스 이용 가능 (약 10분)🕒 운영 시간:오전 10:00 ~ 오후 6:00 (입장 마감 오후 5:30)매주 월요일 휴관 (공휴일일 경우 다음날 휴관)💰 입장료:무료! (Free Admission)📌 박물관 규모는 크지 않지만, 체험 콘텐츠가 많아 1~2시간 정도 여유롭게 즐길 수 있음.스기나미 애니메이션 박물관 – 이런 분들께 추천!✅ 일본 애니메이션을 좋아하는 팬들.✅ 애니메이션 제작 과정을 직접 체험해 보고 싶은 분.✅ 무료로 즐길 수 있는 도쿄의 숨은 명소를 찾는 여행객.✅ 도쿄에서 애니메이션 관련 전시를 관람하고 싶은 분.애니메이션 덕후들의 필수 코스! 🎥✨스기나미 애니메이션 박물관은 단순한 전시 공간이 아니라, 애니메이션의 역사를 배우고 직접 참여할 수 있는 체험형 박물관입니다.도쿄 여행 중 애니메이션에 관심이 있다면 꼭 방문해보세요! 🎨🎬💬 여러분은 어떤 애니메이션의 제작 과정을 체험해보고 싶나요? 😆✨✔️지금 신규로 가입하시면 신규 가입 포인트에!✔️인스타그램 팔로우하시면 인스타그램 팔로우 쿠폰!✔️최대 만오천원 장바구니 쿠폰 이벤트까지 진행하고 있으니!🖐️이로이로도쿄 사이트 방문해서 일본 직구템 잔뜩 담아보시고 다른 곳과 가격 비교해보세요!쉽고 저렴한 일본 직구는 이로이로도쿄!📌 https://iroirotokyo.net
# ==========================================================================================
#
# 4. 링크: https://www.instagram.com/p/DJN0vWHttoZ/
# 완료! 추출된 개수: 52

# %%
# 1) DF 만들기 (url2가 있다고 가정)
sunggi = pd.DataFrame()
sunggi['번호'] = no2
sunggi['아이디'] = pd.Series(id2)
sunggi['내용'] = pd.Series(write2)
sunggi['게시글 링크'] = pd.Series(url2)   # ✅ 일단 URL 문자열로 저장

# 2) 엑셀로 저장
sunggi.to_excel(fx_name, index=False)

# 3) openpyxl로 다시 열어서 "하이퍼링크"로 변환
wb = load_workbook(fx_name)
ws = wb.active

link_col = sunggi.columns.get_loc("게시글 링크") + 1  # openpyxl은 1부터 시작

for row in range(2, ws.max_row + 1):  # 1행은 헤더
    cell = ws.cell(row=row, column=link_col)
    url = cell.value
    if isinstance(url, str) and url.startswith("http"):
        cell.hyperlink = url              # ✅ 하이퍼링크 객체 지정
        cell.style = "Hyperlink"          # ✅ 엑셀 기본 하이퍼링크 스타일(파란색/밑줄)
        # 또는 수동 폰트 적용하고 싶으면:
        # cell.font = Font(color="0000FF", underline="single")

wb.save(fx_name)

# CSV 저장은 그대로(CSV는 하이퍼링크 “객체” 개념이 없음)
sunggi.to_csv(fc_name, encoding="utf-8-sig", index=False)

print('='*80)
print('저장을 완료하였습니다. (엑셀 하이퍼링크 적용 완료)')
print('='*80)
# Out:
# ================================================================================
# 저장을 완료하였습니다. (엑셀 하이퍼링크 적용 완료)
# ================================================================================
